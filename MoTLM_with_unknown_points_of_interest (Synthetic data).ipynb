# %% [markdown]
# ### 1. Import libraries

# %%
import numpy
from numpy import linalg as LA

import import_ipynb
import utility_figures
import Algorithm_of_MoTLM_with_unknown_points_of_interest
# Out:
# importing Jupyter notebook from utility_figures.ipynb
# importing Jupyter notebook from data_analysis.ipynb
# importing Jupyter notebook from Mixtures_of_transparent_local_models_version2.ipynb

# %%
# Influence of quasi Monte Carlo (Mean of 500 random restarts)
####### setup where 0.95 <= values <= 1 #######
n_features = [2, 10, 30]
dists = [0.5, 1, 2]
varepsilon = [1, 0.5, 0.25]
k = [2, 2, 2]
tau = [0.1, 0.1, 0.1]
low_bound = [0.951, 0.951, 0.951]
high_bound = [1.0, 1.0, 1.0]

for i in range(len(k)):
    utility_figures.Influence_of_Quasi_Monte_Carlo(n_features=n_features[i], dists=dists[i], varepsilon=varepsilon[i], k=k[i], tau=tau[i], low_bound=low_bound[i], high_bound=high_bound[i], index=i)

####### setup where 0.449 <= values <= 0.503 #######
n_features = [5, 17, 100]
dists = [1.5, 9, 45]
varepsilon = [1, 0.5, 0.25]
k = [16, 37, 90]
tau = [6.3, 4, 2]
low_bound = [0.449, 0.449, 0.449]
high_bound = [0.503, 0.503, 0.503]

for i in range(len(k)):
    utility_figures.Influence_of_Quasi_Monte_Carlo(n_features=n_features[i], dists=dists[i], varepsilon=varepsilon[i], k=k[i], tau=tau[i], low_bound=low_bound[i], high_bound=high_bound[i], index=i+3)

####### setup where 0.0 <= values <= 0.049 #######
n_features = [4, 7, 11]
dists = [0.5, 1, 2]
varepsilon = [1, 0.5, 0.25]
k = [3, 10, 25]
tau = [9, 20, 25]
low_bound = [0.0, 0.0, 0.0]
high_bound = [0.049, 0.049, 0.049]

for i in range(len(k)):
    utility_figures.Influence_of_Quasi_Monte_Carlo(n_features=n_features[i], dists=dists[i], varepsilon=varepsilon[i], k=k[i], tau=tau[i], low_bound=low_bound[i], high_bound=high_bound[i], index=i+6)

# %% [markdown]
# ### 2. Binary linear classifiers

# %% [markdown]
# #### 2.1. Generate Synthetic Data

# %%
Ntrials = 2000
df_1, target_name, X0_1, BETA_1, situation_1 = utility_figures.DataGenerating_clf(Case=1, LengthRectangle=2.5, WidthRectangle=1.5, Ntrials=Ntrials, lang='en')
utility_figures.PlotDistribution_Synthetic_data_clf_gn(data=df_1, situation=situation_1, learning_type_flag='Search', lang='en')
# Out:
# REGION 1 n_samples : 386, REGION 2 n_samples : 234, REGION EXT n_samples : 772
# Positive class size REGION 1 : 193, Negative class size outside region : 193
# Positive class size REGION 2 : 117, Negative class size outside region : 117
# Positive class size REGION EXT : 386, Negative class size outside region : 386

# %%
Ntrials = 2000
df_2, target_name, X0_2, BETA_2, situation_2 = utility_figures.DataGenerating_clf(Case=2, LengthRectangle=2.5, WidthRectangle=1.5, Ntrials=Ntrials, lang='en')
utility_figures.PlotDistribution_Synthetic_data_clf_gn(data=df_2, situation=situation_2, learning_type_flag='Search', lang='en')
# Out:
# REGION 1 n_samples : 311, REGION 2 n_samples : 57, REGION 3 n_samples : 297, REGION EXT n_samples : 580
# Positive class size REGION 1 : 142, Negative class size outside region : 169
# Positive class size REGION 2 : 57, Negative class size outside region : 0
# Positive class size REGION 3 : 152, Negative class size outside region : 145
# Positive class size REGION EXT : 290, Negative class size outside region : 290

# %% [markdown]
# #### 2.2. Generalization Of Mixture Of Linear Experts Into Many Regions

# %% [markdown]
# ##### Parameters Setting

# %%
train_size=0.70
lr=0.1
lambda_param=300
max_iters=2000
scale=False
lambda_validation=True
times=10
return_flag='complex'

# %% [markdown]
# ##### Situation 1

# %%
lambda_param, X0_1_enc, Epsilon, W, w_ext, MU, mu_ext, K, TAU, BETA, summary, X_train, X_test, ytrain_true, ytest_true, ytrain_pred, ytest_pred = Algorithm_of_MoTLM_with_unknown_points_of_interest.Mixture_clf(df_1.copy(), target_name, n_points=2, train_size=train_size, lr=lr, lambda_param=lambda_param, max_iters=max_iters, scale=scale, lambda_validation=lambda_validation, times=times, return_flag=return_flag)
# Out:
# ***************** Mixtures of transparent local models with unknown points of interest *****************
# Training_set = 70%, Validation_set = 15%, Test_set = 15%, n_points = 2, class_weights = None, scale = False, lambda_validation = True, times = 10
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:59<00:00,
# For Random Data Split = 10 …:  10%|█▎           | 1/10 [05:01<45:13, 301.53s/it]
# C = [[-0.99879676  0.03085747]
#  [ 1.0032516  -0.03191836]], Epsilon = [0.003347 0.00268 ], lambda_param = 1704.5
# K = [44.62665761 50.61515631], TAU = [43.932453 63.478306]
# W = [[-0.06140832 -4.8766513 ]
#  [-0.32556582 -4.54907379]], MU = [0.024877 0.245886]
# w_ext = [0.13964991 5.55375448], mu_ext = -0.269855
# SIGMA = [0.117259 0.078388], sigma_ext = 0.475087
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:36<00:00,
# For Random Data Split = 10 …:  20%|██▌          | 2/10 [09:38<38:17, 287.19s/it]
# C = [[-0.91014352  0.0394289 ]
#  [ 0.99197685 -0.0588562 ]], Epsilon = [0.00285  0.001358], lambda_param = 608.75
# K = [40.27011655 40.53963323], TAU = [39.675441 50.021627]
# W = [[ 1.70297307e-03 -3.48195754e+00]
#  [-4.76463753e-01 -2.63535255e+00]], MU = [-0.091116  0.560073]
# w_ext = [0.24604071 3.90764513], mu_ext = -0.086641
# SIGMA = [0.282176 0.23692 ], sigma_ext = 0.523977
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:43<00:00,
# For Random Data Split = 10 …:  30%|███▉         | 3/10 [14:23<33:24, 286.31s/it]
# C = [[-1.00784357 -0.00473814]
#  [ 1.07681113 -0.01176344]], Epsilon = [0.004039 0.002687], lambda_param = 1704.5
# K = [42.67033747 51.08600501], TAU = [42.978389 63.224809]
# W = [[-0.12358296 -4.98015196]
#  [-0.42717843 -4.47542314]], MU = [-0.301773  0.33173 ]
# w_ext = [0.19573373 5.05583334], mu_ext = -0.189008
# SIGMA = [0.082577 0.120645], sigma_ext = 0.43759
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:11<00:00,
# For Random Data Split = 10 …:  40%|█████▏       | 4/10 [18:36<27:18, 273.17s/it]
# C = [[-0.94193156  0.03006241]
#  [ 0.98579509 -0.06559629]], Epsilon = [0.001713 0.001547], lambda_param = 1095.75
# K = [48.15257978 44.47453182], TAU = [49.089577 56.234426]
# W = [[ 0.35857956 -4.29115922]
#  [-0.03736235 -3.83135472]], MU = [0.141093 0.199845]
# w_ext = [0.20540894 4.68133986], mu_ext = -0.103767
# SIGMA = [0.035522 0.060522], sigma_ext = 0.432877
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:34<00:00,
# For Random Data Split = 10 …:  50%|██████▌      | 5/10 [23:12<22:49, 273.99s/it]
# C = [[-0.98048275  0.05815165]
#  [ 0.98007743 -0.08174769]], Epsilon = [0.001559 0.001868], lambda_param = 1704.5
# K = [47.42235204 52.97386278], TAU = [47.422631 65.890443]
# W = [[-0.02409577 -5.2134378 ]
#  [-0.28003684 -4.64888447]], MU = [-0.105308  0.241147]
# w_ext = [0.13662051 5.31817419], mu_ext = -0.455301
# SIGMA = [0.086036 0.074562], sigma_ext = 0.466789
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:29<00:00,
# For Random Data Split = 10 …:  60%|███████▊     | 6/10 [27:43<18:11, 272.99s/it]
# C = [[-0.94980125  0.06728712]
#  [ 1.02739663 -0.06831412]], Epsilon = [0.003766 0.003327], lambda_param = 730.5
# K = [51.86581084 37.67695732], TAU = [50.730752 47.095145]
# W = [[-0.07991284 -3.70244382]
#  [-0.14225792 -3.23653406]], MU = [-0.157355  0.348128]
# w_ext = [0.15440801 4.32022746], mu_ext = -0.384292
# SIGMA = [0.11187  0.074374], sigma_ext = 0.365709
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:24<00:00,
# For Random Data Split = 10 …:  70%|█████████    | 7/10 [32:09<13:32, 270.72s/it]
# C = [[-0.98975558 -0.00219599]
#  [ 0.98519773 -0.01934006]], Epsilon = [0.002223 0.001837], lambda_param = 730.5
# K = [45.74293751 42.99810747], TAU = [46.428541 54.038848]
# W = [[ 0.2041256  -3.74235774]
#  [-0.20790113 -3.13657531]], MU = [-0.050665  0.249371]
# w_ext = [0.26287508 4.15978946], mu_ext = -0.196891
# SIGMA = [0.047917 0.060489], sigma_ext = 0.402831
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:26<00:00,
# For Random Data Split = 10 …:  80%|██████████▍  | 8/10 [36:37<08:59, 269.90s/it]
# C = [[-0.99236179  0.01441714]
#  [ 1.005174   -0.0619944 ]], Epsilon = [0.003217 0.005457], lambda_param = 2435.0
# K = [41.88314201 43.95525815], TAU = [40.919628 54.761423]
# W = [[ 0.00703358 -5.6685505 ]
#  [-0.1588797  -5.11541562]], MU = [-0.22886  0.15689]
# w_ext = [0.22380057 5.64678667], mu_ext = 0.081737
# SIGMA = [0.196266 0.024288], sigma_ext = 0.487385
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:28<00:00,
# For Random Data Split = 10 …:  90%|███████████▋ | 9/10 [41:07<04:29, 269.90s/it]
# C = [[-0.92016348  0.12021667]
#  [ 1.02261177 -0.053559  ]], Epsilon = [0.002187 0.000322], lambda_param = 608.75
# K = [39.21924996 42.33888797], TAU = [37.877652 49.58202 ]
# W = [[ 0.09885844 -3.57737625]
#  [-0.43906133 -2.79457969]], MU = [0.018926 0.470807]
# w_ext = [-0.18724795  3.92268998], mu_ext = 0.237841
# SIGMA = [0.272879 0.226726], sigma_ext = 0.572337
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [04:26<00:00,
# For Random Data Split = 10 …: 100%|████████████| 10/10 [45:35<00:00, 273.55s/it]
# C = [[-0.93924792  0.06096407]
#  [ 0.97897302 -0.04660478]], Epsilon = [0.003624 0.003553], lambda_param = 1826.25
# K = [49.89378869 44.90510389], TAU = [50.463053 57.433567]
# W = [[ 0.11559661 -5.22331419]
#  [ 0.02661404 -4.66339617]], MU = [0.096435 0.10833 ]
# w_ext = [0.27731757 5.46129074], mu_ext = -0.332482
# SIGMA = [0.097614 0.039036], sigma_ext = 0.534592
# *********** END ***********
# C = [[-0.96305282  0.04144513]
#  [ 1.00572652 -0.04996943]], Epsilon = [0.002853 0.002464], K = [45.17469725 45.15635039], TAU = [44.951812 56.176061]
# W = [[ 0.04968969 -4.47574003]
#  [-0.24680933 -3.90865895]], MU = [-0.065375  0.291221]
# w_ext = [0.16546071 4.80275313], mu_ext = -0.169866
# SIGMA = [0.133012 0.099595], sigma_ext = 0.469917

# %%
summary
# Out:
#                 Accuracy  F1_score  Precision_score  Gibbs_risk  Risk_bound
# Training set      77.915    77.776           71.860      0.2987      0.3605
# Validation set    79.664    79.576           74.018      0.2898      0.3515
# Testing set       77.224    77.019           70.975      0.3010      0.3628

# %%
Mat_dists_train = LA.norm((X0_1_enc.reshape(X0_1_enc.shape[0], 1, X0_1_enc.shape[1]) - X_train), axis=2)
utility_figures.visualize_hybrid_hyperplane_gn(X=X_train, y=ytrain_true, Xcenter=X0_1_enc, dist_type='euclidean', Mat_dists=Mat_dists_train, V=W, v_ext=w_ext, B=MU, b_ext=mu_ext, BETA=BETA, situation=situation_1, jeu='Jeu d\'entraînement', option=False, learning_type_flag='Search', lang='en')

# %%
Mat_dists_test = LA.norm((X0_1_enc.reshape(X0_1_enc.shape[0], 1, X0_1_enc.shape[1]) - X_test), axis=2)
utility_figures.visualize_hybrid_hyperplane_gn(X=X_test, y=ytest_true, Xcenter=X0_1_enc, dist_type='euclidean', Mat_dists=Mat_dists_test, V=W, v_ext=w_ext, B=MU, b_ext=mu_ext, BETA=BETA, situation=situation_1, jeu='Jeu de test', option=False, learning_type_flag='Search', lang='en')

# %% [markdown]
# ##### Situation 2

# %%
lambda_param_, X0_2_enc, Epsilon_, W_, w_ext_, MU_, mu_ext_, K_, TAU_, BETA_, summary_, X_train_, X_test_, ytrain_true_, ytest_true_, ytrain_pred_, ytest_pred_ = Algorithm_of_MoTLM_with_unknown_points_of_interest.Mixture_clf(df_2.copy(), target_name, n_points=3, train_size=train_size, lr=lr, lambda_param=lambda_param, max_iters=max_iters, scale=scale, lambda_validation=lambda_validation, times=times, return_flag=return_flag)
# Out:
# ***************** Mixtures of transparent local models with unknown points of interest *****************
# Training_set = 70%, Validation_set = 15%, Test_set = 15%, n_points = 3, class_weights = None, scale = False, lambda_validation = True, times = 10
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:25<00:00,
# For Random Data Split = 10 …:  10%|█          | 1/10 [09:26<1:25:01, 566.88s/it]
# C = [[-1.35726917  0.00422978]
#  [-0.08323604  0.68317123]
#  [ 1.39863344  0.01549952]], Epsilon = [0.001872 0.016514 0.002126], lambda_param = 435.5
# K = [45.68901757 18.51962506 49.76763496], TAU = [51.321117 42.129892 57.798893]
# W = [[ 0.13858165  3.94966905]
#  [ 0.04758254  0.78871509]
#  [-0.1445653   3.82360058]], MU = [0.165817 0.956991 0.272944]
# w_ext = [-0.08214126 -3.76333017], mu_ext = -0.130179
# SIGMA = [0.087593 0.307521 0.145082], sigma_ext = 0.158729
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:37<00:00,
# For Random Data Split = 10 …:  20%|██▏        | 2/10 [19:06<1:16:34, 574.27s/it]
# C = [[-1.4340879  -0.03523593]
#  [-0.02726719  0.81123338]
#  [ 1.37978612 -0.03399538]], Epsilon = [0.000356 0.003398 0.001946], lambda_param = 943.5833333333333
# K = [39.9065666  19.64052935 45.70369241], TAU = [45.156675 48.964939 53.022748]
# W = [[0.20801188 5.43750411]
#  [0.03015879 0.87460399]
#  [0.075702   5.30934801]], MU = [0.191657 1.139556 0.14449 ]
# w_ext = [-0.008481   -4.53441849], mu_ext = -0.157363
# SIGMA = [0.112041 0.296528 0.220181], sigma_ext = 0.238056
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:53<00:00,
# For Random Data Split = 10 …:  30%|███▎       | 3/10 [29:01<1:08:07, 583.99s/it]
# C = [[-1.35189597  0.00505894]
#  [-0.01687908  0.77544161]
#  [ 1.41157699 -0.01503663]], Epsilon = [0.002662 0.000107 0.00118 ], lambda_param = 435.5
# K = [42.99141519 29.60937595 42.7932197 ], TAU = [47.568145 75.630863 50.097946]
# W = [[0.21510575 4.02980862]
#  [0.0105331  0.80607732]
#  [0.05451386 3.97652739]], MU = [ 0.099747  0.990531 -0.06891 ]
# w_ext = [ 0.00614614 -3.63198094], mu_ext = -0.123546
# SIGMA = [0.085958 0.232029 0.101746], sigma_ext = 0.1209
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:50<00:00,
# For Random Data Split = 10 …:  40%|█████▏       | 4/10 [38:54<58:44, 587.40s/it]
# C = [[-1.41922261 -0.002622  ]
#  [-0.00258709  0.80255045]
#  [ 1.40803005  0.01788786]], Epsilon = [0.001923 0.000628 0.000788], lambda_param = 1379.0833333333333
# K = [43.87405439 29.34764444 41.5605542 ], TAU = [50.350654 74.144319 47.768989]
# W = [[0.35902392 6.27503729]
#  [0.01080341 1.03878522]
#  [0.04936544 6.17260142]], MU = [0.312561 1.232372 0.182065]
# w_ext = [-0.1253121  -4.90907527], mu_ext = -0.221642
# SIGMA = [0.110633 0.217012 0.067192], sigma_ext = 0.258508
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:32<00:00,
# For Random Data Split = 10 …:  50%|██████▌      | 5/10 [48:28<48:32, 582.52s/it]
# C = [[-1.39335567  0.01555312]
#  [-0.01483273  0.73157643]
#  [ 1.41716993 -0.02092816]], Epsilon = [0.001345 0.002091 0.002492], lambda_param = 1016.1666666666665
# K = [46.07650574 33.2899221  46.99980918], TAU = [53.395487 84.521347 54.440034]
# W = [[ 0.0774773   5.48693078]
#  [ 0.00786836  0.97556387]
#  [-0.01191078  5.66598511]], MU = [-0.007272  1.156679  0.140775]
# w_ext = [-0.01632154 -4.56468781], mu_ext = -0.121584
# SIGMA = [0.070372 0.23204  0.111338], sigma_ext = 0.285404
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:26<00:00,
# For Random Data Split = 10 …:  60%|███████▊     | 6/10 [57:56<38:31, 577.78s/it]
# C = [[-1.42243558 -0.08390311]
#  [-0.06332793  0.77105185]
#  [ 1.39402872 -0.01984957]], Epsilon = [0.001139 0.00207  0.001685], lambda_param = 943.5833333333333
# K = [47.20287479 23.26527149 40.85026108], TAU = [53.854637 58.58762  47.567145]
# W = [[ 0.33074022  5.36815917]
#  [-0.006306    0.90800799]
#  [ 0.27669556  5.42221648]], MU = [ 0.409955  1.131172 -0.006448]
# w_ext = [ 0.03565424 -4.40448658], mu_ext = -0.236794
# SIGMA = [0.032495 0.149785 0.117032], sigma_ext = 0.080155
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:26<00:00,
# For Random Data Split = 10 …:  70%|███████▋   | 7/10 [1:07:25<28:43, 574.62s/it]
# C = [[-1.42498012  0.04556402]
#  [ 0.05220829  0.82899997]
#  [ 1.38747684 -0.02189254]], Epsilon = [0.00162 0.0007  0.00325], lambda_param = 943.5833333333333
# K = [42.24654769 22.03654107 41.35114545], TAU = [48.352391 52.726485 47.277472]
# W = [[0.12311179 5.53062043]
#  [0.05604624 0.98806649]
#  [0.0936534  5.39343619]], MU = [ 0.123868  1.178435 -0.0917  ]
# w_ext = [-0.1209133 -4.5008225], mu_ext = -0.175943
# SIGMA = [0.109128 0.229008 0.249205], sigma_ext = 0.216411
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:50<00:00,
# For Random Data Split = 10 …:  80%|████████▊  | 8/10 [1:17:17<19:20, 580.30s/it]
# C = [[-1.45178693  0.02096269]
#  [ 0.03568427  0.72613474]
#  [ 1.38431258 -0.03078876]], Epsilon = [0.003365 0.000494 0.000717], lambda_param = 1379.0833333333333
# K = [46.17081293 28.01971537 46.52600559], TAU = [51.184804 69.67139  51.90267 ]
# W = [[ 0.01013655  6.2893013 ]
#  [-0.01094835  1.03499287]
#  [ 0.02734032  6.29819994]], MU = [-0.209996  1.222452  0.268126]
# w_ext = [-0.06374223 -4.94481797], mu_ext = -0.105717
# SIGMA = [0.16236  0.174606 0.11101 ], sigma_ext = 0.260051
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:34<00:00,
# For Random Data Split = 10 …:  90%|█████████▉ | 9/10 [1:26:54<09:39, 579.25s/it]
# C = [[-1.39484674 -0.01125937]
#  [ 0.03374136  0.79279779]
#  [ 1.37968121 -0.01153502]], Epsilon = [0.00296  0.000432 0.005933], lambda_param = 943.5833333333333
# K = [50.34351204 20.25082764 43.61627779], TAU = [56.796729 51.790038 50.860481]
# W = [[ 0.15494481  5.6111955 ]
#  [ 0.02533753  0.86616545]
#  [-0.14675528  5.3290086 ]], MU = [0.114836 1.096839 0.246263]
# w_ext = [-0.18632443 -4.42652261], mu_ext = -0.089777
# SIGMA = [0.04757  0.133998 0.135299], sigma_ext = 0.09253
# Tuning Lambda (30 random restarts for each lambda) : 100%|█| 17/17 [09:34<00:00,
# For Random Data Split = 10 …: 100%|██████████| 10/10 [1:36:31<00:00, 579.15s/it]
# C = [[-1.38220705e+00  1.44504386e-02]
#  [-1.38690699e-02  7.40766016e-01]
#  [ 1.37285854e+00  9.25733937e-04]], Epsilon = [4.300e-05 3.154e-03 2.864e-03], lambda_param = 653.25
# K = [49.64753613 18.48922299 40.01437272], TAU = [57.581888 48.711582 45.820175]
# W = [[ 2.65220647e-01  4.76585818e+00]
#  [-1.31283634e-03  7.90344019e-01]
#  [ 4.62396389e-02  4.72408523e+00]], MU = [0.057924 1.017273 0.143462]
# w_ext = [ 0.03261098 -3.9848015 ], mu_ext = -0.051857
# SIGMA = [0.097582 0.212276 0.072199], sigma_ext = 0.092587
# *********** END ***********
# C = [[-1.40320877 -0.00272014]
#  [-0.01003652  0.76637235]
#  [ 1.39335544 -0.01197129]], Epsilon = [0.001729 0.002959 0.002298], K = [45.41488431 24.24686755 43.91829731], TAU = [51.556253 60.687848 50.655655]
# W = [[0.18823545 5.27440844]
#  [0.01697628 0.90713223]
#  [0.03202788 5.2115009 ]], MU = [0.12591  1.11223  0.123107]
# w_ext = [-0.05288245 -4.36649438], mu_ext = -0.14144
# SIGMA = [0.091573 0.21848  0.133028], sigma_ext = 0.180333

# %%
summary_
# Out:
#                 Accuracy  F1_score  Precision_score  Gibbs_risk  Risk_bound
# Training set      96.636    96.715           95.394      0.1681      0.2922
# Validation set    97.007    97.081           95.813      0.1720      0.2961
# Testing set       95.187    95.328           93.644      0.1758      0.2998

# %%
Mat_dists_train_ = LA.norm((X0_2_enc.reshape(X0_2_enc.shape[0], 1, X0_2_enc.shape[1]) - X_train_), axis=2)
utility_figures.visualize_hybrid_hyperplane_gn(X=X_train_, y=ytrain_true_, Xcenter=X0_2_enc, dist_type='euclidean', Mat_dists=Mat_dists_train_, V=W_, v_ext=w_ext_, B=MU_, b_ext=mu_ext_, BETA=BETA_, situation=situation_2, jeu='Jeu d\'entraînement', option=False, learning_type_flag='Search', lang='en')

# %%
Mat_dists_test_ = LA.norm((X0_2_enc.reshape(X0_2_enc.shape[0], 1, X0_2_enc.shape[1]) - X_test_), axis=2)
utility_figures.visualize_hybrid_hyperplane_gn(X=X_test_, y=ytest_true_, Xcenter=X0_2_enc, dist_type='euclidean', Mat_dists=Mat_dists_test_, V=W_, v_ext=w_ext_, B=MU_, b_ext=mu_ext_, BETA=BETA_, situation=situation_2, jeu='Jeu de test', option=False, learning_type_flag='Search', lang='en')

# %% [markdown]
# ### 3. Linear regression

# %% [markdown]
# #### 3.1. Generate Synthetic Data

# %%
Ntrials = 500
df_1, target_name, X0_1, Y0_1, BETA_1, situation_1 = utility_figures.DataGenerating_reg(Case=1, Ntrials=Ntrials, lang='en')
utility_figures.PlotDistribution_Synthetic_data_reg_gn(data=df_1, situation=situation_1, learning_type_flag='Search', lang='en')
# Out:
# REGION 1 n_samples : 386, REGION EXT n_samples : 320

# %%
Ntrials = 500
df_2, target_name, X0_2, Y0_2, BETA_2, situation_2 = utility_figures.DataGenerating_reg(Case=2, Ntrials=Ntrials, lang='en')
utility_figures.PlotDistribution_Synthetic_data_reg_gn(data=df_2, situation=situation_2, learning_type_flag='Search', lang='en')
# Out:
# REGION 1 n_samples : 353, REGION 2 n_samples : 353, REGION EXT n_samples : 352

# %% [markdown]
# #### 3.2. Generalization Of Mixture Of Linear Experts Into Many Regions

# %% [markdown]
# ##### Parameters Setting

# %%
train_size=0.70
lr=0.1
lambda_param=200
max_iters=2000
scale=False
lambda_validation=True
times=times
check_multicollinearity=True
return_flag='complex'

# %% [markdown]
# ##### Situation 1

# %%
lambda_param, X0_1_enc, Epsilon, W, w_ext, MU, mu_ext, K, TAU, BETA, summary, X_train, X_test, ytrain_true, ytest_true, ytrain_pred, ytest_pred = Algorithm_of_MoTLM_with_unknown_points_of_interest.Mixture_reg(df_1.copy(), target_name, synthetic_data_flag=True, n_points=1, train_size=train_size, lr=lr, lambda_param=lambda_param, max_iters=max_iters, scale=scale, lambda_validation=lambda_validation, times=times, check_multicollinearity=check_multicollinearity, return_flag=return_flag)
# Out:
# ***************** Mixtures of transparent local models without given points of interest *****************
# Training_set = 70%, Validation_set = 15%, Test_set = 15%, n_points = 1, weights = None, scale = False, lambda_validation = True, times = 10, check_multicollinearity = True
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:06<00:00,
# For Random Data Split = 10 …:  10%|█▎           | 1/10 [02:08<19:19, 128.78s/it]
# C = [[0.01904475]], Epsilon = [1.9e-05], lambda_param = 1605.5
# W = [[0.50136133]], MU = [-0.002308]
# w_ext = [-0.54552875], mu_ext = 0.038625
# RHO = [0.01722758], SIGMA = [0.017041]
# rho_ext = 0.021071682078305336, sigma_ext = 0.024426
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:13<00:00,
# For Random Data Split = 10 …:  20%|██▌          | 2/10 [04:24<17:40, 132.60s/it]
# C = [[0.02572449]], Epsilon = [0.002458], lambda_param = 741.0
# W = [[0.47668857]], MU = [-0.012454]
# w_ext = [-0.53937592], mu_ext = 0.02356
# RHO = [0.03770664], SIGMA = [0.022701]
# rho_ext = 0.03471497111891926, sigma_ext = 0.048906
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:03<00:00,
# For Random Data Split = 10 …:  30%|███▉         | 3/10 [06:29<15:05, 129.39s/it]
# C = [[-0.00864682]], Epsilon = [0.001479], lambda_param = 2470.0
# W = [[0.49108459]], MU = [-0.017319]
# w_ext = [-0.54128942], mu_ext = 0.014285
# RHO = [0.01741273], SIGMA = [0.012351]
# rho_ext = 0.021343384951300313, sigma_ext = 0.031114
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:01<00:00,
# For Random Data Split = 10 …:  40%|█████▏       | 4/10 [08:33<12:43, 127.28s/it]
# C = [[0.00313153]], Epsilon = [0.001103], lambda_param = 2223.0
# W = [[0.49545804]], MU = [-0.013738]
# w_ext = [-0.5447873], mu_ext = 0.023148
# RHO = [0.08709099], SIGMA = [0.01905]
# rho_ext = 0.01698127440470693, sigma_ext = 0.02307
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:11<00:00,
# For Random Data Split = 10 …:  50%|██████▌      | 5/10 [10:47<10:48, 129.63s/it]
# C = [[0.01423751]], Epsilon = [0.001484], lambda_param = 1358.5
# W = [[0.47968549]], MU = [-0.006026]
# w_ext = [-0.54348421], mu_ext = 0.032562
# RHO = [0.00351462], SIGMA = [0.001927]
# rho_ext = 0.023432837907959716, sigma_ext = 0.053575
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:09<00:00,
# For Random Data Split = 10 …:  60%|███████▊     | 6/10 [12:59<08:41, 130.42s/it]
# C = [[0.03773692]], Epsilon = [0.002151], lambda_param = 1605.5
# W = [[0.49251977]], MU = [0.001807]
# w_ext = [-0.54476007], mu_ext = 0.052976
# RHO = [0.00936432], SIGMA = [0.009716]
# rho_ext = 0.012323370985662961, sigma_ext = 0.014598
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:11<00:00,
# For Random Data Split = 10 …:  70%|█████████    | 7/10 [15:13<06:34, 131.54s/it]
# C = [[0.02817742]], Epsilon = [0.0099], lambda_param = 1111.5
# W = [[0.51026976]], MU = [-0.031502]
# w_ext = [-0.54030268], mu_ext = 0.019888
# RHO = [0.03068379], SIGMA = [0.030893]
# rho_ext = 0.0347563192563433, sigma_ext = 0.037831
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:15<00:00,
# For Random Data Split = 10 …:  80%|██████████▍  | 8/10 [17:30<04:26, 133.35s/it]
# C = [[0.02127733]], Epsilon = [0.000456], lambda_param = 864.5
# W = [[0.4874372]], MU = [-0.003139]
# w_ext = [-0.54282883], mu_ext = 0.035114
# RHO = [0.05513033], SIGMA = [0.028945]
# rho_ext = 0.03301500499558087, sigma_ext = 0.040845
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:14<00:00,
# For Random Data Split = 10 …:  90%|███████████▋ | 9/10 [19:47<02:14, 134.52s/it]
# C = [[0.02622712]], Epsilon = [0.002728], lambda_param = 2223.0
# W = [[0.47985457]], MU = [-0.000326]
# w_ext = [-0.54330903], mu_ext = 0.049746
# RHO = [0.00868011], SIGMA = [0.007693]
# rho_ext = 0.01241312266846337, sigma_ext = 0.017112
# Tuning Lambda (10 random restarts for each lambda) : 100%|█| 17/17 [02:16<00:00,
# For Random Data Split = 10 …: 100%|████████████| 10/10 [22:06<00:00, 132.69s/it]
# C = [[0.01843273]], Epsilon = [0.003402], lambda_param = 864.5
# W = [[0.47843524]], MU = [-0.006989]
# w_ext = [-0.54271623], mu_ext = 0.049837
# RHO = [0.03205187], SIGMA = [0.013874]
# rho_ext = 0.020090824530323657, sigma_ext = 0.030012
# *********** END ***********
# C = [[0.0185343]], Epsilon = [0.002518]
# W = [[0.48927945]], MU = [-0.009199]
# w_ext = [-0.54283824], mu_ext = 0.033974
# RHO = [0.0298863], SIGMA = [0.016419]
# rho_ext = 0.023014279289756568, sigma_ext = 0.032149

# %%
summary
# Out:
#                 R2_score    RMSE     MSE  Gibbs_risk  Risk_bound
# Training set      0.9978  0.0258  0.0007      0.0165      0.0363
# Validation set    0.9980  0.0244  0.0006      0.0169      0.0367
# Testing set       0.9978  0.0256  0.0007      0.0176      0.0374

# %%
Mat_dists_train = LA.norm((X0_1_enc.reshape(X0_1_enc.shape[0], 1, X0_1_enc.shape[1]) - X_train), axis=2)
xmin, xmax, ymin, ymax = utility_figures.get_xlimit_ylimit_hybrid_gn(X=X_train, y=ytrain_true, Xc=X0_1_enc, dist_type='euclidean', Mat_dists=Mat_dists_train, V=W, v_ext=w_ext, B=MU, b_ext=mu_ext, BETA=BETA)
utility_figures.visualize_hybrid_lr_reg_gn(X=X_train, y=ytrain_true, Xc=X0_1_enc, Yc=Y0_1, dist_type='euclidean', Mat_dists=Mat_dists_train, V=W, v_ext=w_ext, B=MU, b_ext=mu_ext, BETA=BETA, xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax, situation=situation_1, jeu='Apprentissage', learning_type_flag='Search', lang='en')

# %%
Mat_dists_test = LA.norm((X0_1_enc.reshape(X0_1_enc.shape[0], 1, X0_1_enc.shape[1]) - X_test), axis=2)
utility_figures.visualize_hybrid_lr_reg_gn(X=X_test, y=ytest_true, Xc=X0_1_enc, Yc=Y0_1, dist_type='euclidean', Mat_dists=Mat_dists_test, V=W, v_ext=w_ext, B=MU, b_ext=mu_ext, BETA=BETA, xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax, situation=situation_1, jeu='Tester', learning_type_flag='Search', lang='en')

# %% [markdown]
# ##### Situation 2

# %%
lambda_param_, X0_2_enc, Epsilon_, W_, w_ext_, MU_, mu_ext_, K_, TAU_, BETA_, summary_, X_train_, X_test_, ytrain_true_, ytest_true_, ytrain_pred_, ytest_pred_ = Algorithm_of_MoTLM_with_unknown_points_of_interest.Mixture_reg(df_2.copy(), target_name, synthetic_data_flag=True, n_points=2, train_size=train_size, lr=lr, lambda_param=lambda_param, max_iters=max_iters, scale=scale, lambda_validation=lambda_validation, times=times, check_multicollinearity=check_multicollinearity, return_flag=return_flag)
# Out:
# ***************** Mixtures of transparent local models without given points of interest *****************
# Training_set = 70%, Validation_set = 15%, Test_set = 15%, n_points = 2, weights = None, scale = False, lambda_validation = True, times = 10, check_multicollinearity = True
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:24<00:00,
# For Random Data Split = 10 …:  10%|█          | 1/10 [12:28<1:52:14, 748.26s/it]
# C = [[-0.5071327 ]
#  [ 0.50458696]], Epsilon = [0.002656 0.001343], lambda_param = 925.0
# W = [[ 1.93889492]
#  [-2.0426099 ]], MU = [0.945813 0.990078]
# w_ext = [0.01458282], mu_ext = 0.014273
# RHO = [9.18689058e-05 1.02286373e-01], SIGMA = [0.00044  0.050057]
# rho_ext = 0.0395407533390567, sigma_ext = 0.102574
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:06<00:00,
# For Random Data Split = 10 …:  20%|██▏        | 2/10 [24:38<1:38:19, 737.39s/it]
# C = [[-0.44234925]
#  [ 0.46420899]], Epsilon = [0.004363 0.00046 ], lambda_param = 1850.0
# W = [[ 1.94145327]
#  [-2.02572006]], MU = [1.043621 1.038912]
# w_ext = [-0.01837023], mu_ext = 0.066908
# RHO = [0.02941216 0.00849383], SIGMA = [0.031075 0.000609]
# rho_ext = 0.06928413355247809, sigma_ext = 0.156718
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:24<00:00,
# For Random Data Split = 10 …:  30%|███▎       | 3/10 [37:05<1:26:34, 742.01s/it]
# C = [[-0.53506722]
#  [ 0.52339559]], Epsilon = [0.002253 0.003258], lambda_param = 1850.0
# W = [[ 2.05979312]
#  [-2.00279028]], MU = [1.000805 0.984566]
# w_ext = [-0.01893478], mu_ext = 0.042528
# RHO = [0.01583696 0.00295786], SIGMA = [0.017682 0.000121]
# rho_ext = 0.04475955524615957, sigma_ext = 0.125812
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:22<00:00,
# For Random Data Split = 10 …:  40%|████▍      | 4/10 [49:31<1:14:20, 743.50s/it]
# C = [[-0.50112013]
#  [ 0.47748042]], Epsilon = [0.003114 0.003231], lambda_param = 1110.0
# W = [[ 2.01102144]
#  [-1.98943268]], MU = [1.010972 1.020191]
# w_ext = [0.01061999], mu_ext = 0.034311
# RHO = [0.00121491 0.01684253], SIGMA = [0.       0.003078]
# rho_ext = 0.07037596914758946, sigma_ext = 0.17491
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:14<00:00,
# For Random Data Split = 10 …:  50%|████▌    | 5/10 [1:01:49<1:01:48, 741.61s/it]
# C = [[-0.49724484]
#  [ 0.48646016]], Epsilon = [0.000787 0.001235], lambda_param = 925.0
# W = [[ 2.00874814]
#  [-2.03279343]], MU = [1.004384 1.036421]
# w_ext = [0.02250734], mu_ext = 0.039854
# RHO = [7.25805227e-07 6.50678944e-02], SIGMA = [9.0000e-06 3.0377e-02]
# rho_ext = 0.02531390921927678, sigma_ext = 0.077791
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:04<00:00,
# For Random Data Split = 10 …:  60%|██████▌    | 6/10 [1:13:56<49:07, 736.76s/it]
# C = [[-0.47214275]
#  [ 0.56904241]], Epsilon = [0.000911 0.004571], lambda_param = 925.0
# W = [[ 2.02556611]
#  [-2.0459626 ]], MU = [1.031341 1.05307 ]
# w_ext = [0.00010526], mu_ext = 0.035659
# RHO = [3.22413546e-16 1.43099248e-01], SIGMA = [0.       0.080192]
# rho_ext = 0.06387905387967592, sigma_ext = 0.143551
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:22<00:00,
# For Random Data Split = 10 …:  70%|███████▋   | 7/10 [1:26:23<36:59, 739.81s/it]
# C = [[-0.48628233]
#  [ 0.49824603]], Epsilon = [0.000411 0.000713], lambda_param = 1850.0
# W = [[ 2.00006247]
#  [-2.04524832]], MU = [1.033951 1.027957]
# w_ext = [-0.0122502], mu_ext = 0.029942
# RHO = [0.00856365 0.00108671], SIGMA = [9.108e-03 1.500e-05]
# rho_ext = 0.028193382119673982, sigma_ext = 0.092706
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [12:09<00:00,
# For Random Data Split = 10 …:  80%|████████▊  | 8/10 [1:38:36<24:35, 737.78s/it]
# C = [[-0.51896944]
#  [ 0.45220151]], Epsilon = [0.002142 0.00588 ], lambda_param = 1850.0
# W = [[ 2.08769471]
#  [-2.05087072]], MU = [1.029425 1.020545]
# w_ext = [-0.00011642], mu_ext = 0.020082
# RHO = [0.00822462 0.00122578], SIGMA = [8.833e-03 2.000e-05]
# rho_ext = 0.028267366888012613, sigma_ext = 0.092878
# Tuning Lambda (20 random restarts for each lambda) : 100%|█| 17/17 [26:08<00:00,
# For Random Data Split = 10 …:  90%|█████████ | 9/10 [2:04:54<16:40, 1000.60s/it]
# C = [[-0.52604616]
#  [ 0.49237397]], Epsilon = [0.001218 0.001993], lambda_param = 1850.0
# W = [[ 2.07623888]
#  [-2.07820956]], MU = [1.024798 1.049198]
# w_ext = [0.01030157], mu_ext = 0.021407
# RHO = [0.00472597 0.00034416], SIGMA = [0.005453 0.      ]
# rho_ext = 0.017310726868401956, sigma_ext = 0.06819
# Tuning Lambda (20 random restarts for each lambda) :  29%|▎| 5/17 [36:11<1:26:52
# For Random Data Split = 10 …: 100%|██████████| 10/10 [2:41:15<00:00, 967.58s/it]
# C = [[-0.48171221]
#  [ 0.51610359]], Epsilon = [0.006045 0.000753], lambda_param = 740.0
# W = [[ 1.95598365]
#  [-2.02084007]], MU = [1.000338 1.012503]
# w_ext = [-0.01437339], mu_ext = -0.004334
# RHO = [0.02663908 0.04071763], SIGMA = [0.008411 0.037458]
# rho_ext = 0.06416253633690992, sigma_ext = 0.146233
# *********** END ***********
# C = [[-0.4968067 ]
#  [ 0.49840996]], Epsilon = [0.00239  0.002344]
# W = [[ 2.01054567]
#  [-2.03344776]], MU = [1.012545 1.023344]
# w_ext = [-0.0005928], mu_ext = 0.030063
# RHO = [0.00947099 0.0382122 ], SIGMA = [0.008101 0.020193]
# rho_ext = 0.0451087386597235, sigma_ext = 0.118136

# %%
summary_
# Out:
#                 R2_score    RMSE     MSE  Gibbs_risk  Risk_bound
# Training set      0.9848  0.0532  0.0029      0.0265      0.0770
# Validation set    0.9852  0.0520  0.0028      0.0288      0.0793
# Testing set       0.9848  0.0521  0.0028      0.0261      0.0766

# %%
Mat_dists_train_ = LA.norm((X0_2_enc.reshape(X0_2_enc.shape[0], 1, X0_2_enc.shape[1]) - X_train_), axis=2)
xmin_, xmax_, ymin_, ymax_ = utility_figures.get_xlimit_ylimit_hybrid_gn(X=X_train_, y=ytrain_true_, Xc=X0_2_enc, dist_type='euclidean', Mat_dists=Mat_dists_train_, V=W_, v_ext=w_ext_, B=MU_, b_ext=mu_ext_, BETA=BETA_)
utility_figures.visualize_hybrid_lr_reg_gn(X=X_train_, y=ytrain_true_, Xc=X0_2_enc, Yc=Y0_2, dist_type='euclidean', Mat_dists=Mat_dists_train_, V=W_, v_ext=w_ext_, B=MU_, b_ext=mu_ext_, BETA=BETA_, xmin=xmin_, xmax=xmax_, ymin=ymin_, ymax=ymax_, situation=situation_2, jeu='Apprentissage', learning_type_flag='Search', lang='en')

# %%
Mat_dists_test_ = LA.norm((X0_2_enc.reshape(X0_2_enc.shape[0], 1, X0_2_enc.shape[1]) - X_test_), axis=2)
utility_figures.visualize_hybrid_lr_reg_gn(X=X_test_, y=ytest_true_, Xc=X0_2_enc, Yc=Y0_2, dist_type='euclidean', Mat_dists=Mat_dists_test_, V=W_, v_ext=w_ext_, B=MU_, b_ext=mu_ext_, BETA=BETA_, xmin=xmin_, xmax=xmax_, ymin=ymin_, ymax=ymax_, situation=situation_2, jeu='Tester', learning_type_flag='Search', lang='en')
